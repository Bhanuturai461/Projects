# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
from pyspark.sql import *
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 3, Finished, Available, Finished)

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS Lakehouse_Demo.Dim_OrderReturn
# (
#     Order_ID string,
#     Return string,
#     Order_Year int,
#     Order_Month int,
#     Created_TS TIMESTAMP,
#     Modified_TS TIMESTAMP
# )
# USING delta
# PARTITIONED BY (Order_Year, Order_Month);
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 9, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
Max_Date=spark.sql("select coalesce(max(Modified_TS),'1900-01-01') from Lakehouse_Demo.Dim_OrderReturn").first()[0]
print(Max_Date)
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 15, Finished, Available, Finished)
# 1900-01-01

# %%
df=spark.sql("""select Order_ID  ,
Return ,
Order_Year, 
Order_Month ,
Created_TS ,
Modified_TS 
from Lakehouse_Demo.Sales_Stg where Return="Yes" and Modified_TS>'{}'""".format(Max_Date))
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 16, Finished, Available, Finished)

# %%
df.createOrReplaceTempView("ViewReturn")
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 17, Finished, Available, Finished)

# %%
# %%sql
# insert into Lakehouse_Demo.Dim_OrderReturn
# select * from ViewReturn
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 19, Finished, Available, Finished)
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# select * from Lakehouse_Demo.Dim_OrderReturn
# Out:
# StatementMeta(, 64fc69f3-0441-4aee-a4f0-cd8d9f6d6377, 20, Finished, Available, Finished)
# <Spark SQL result set with 123 rows and 6 fields>
